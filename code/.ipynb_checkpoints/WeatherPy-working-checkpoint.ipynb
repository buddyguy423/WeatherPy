# %% [markdown]
# # WeatherPy
# ----
#
# ### Analysis
# * As expected, the weather becomes significantly warmer as one approaches the equator (0 Deg. Latitude). More interestingly, however, is the fact that the southern hemisphere tends to be warmer this time of year than the northern hemisphere. This may be due to the tilt of the earth.
# * There is no strong relationship between latitude and cloudiness. However, it is interesting to see that a strong band of cities sits at 0, 80, and 100% cloudiness.
# * There is no strong relationship between latitude and wind speed. However, in northern hemispheres there is a flurry of cities with over 20 mph of wind.
#
# ---
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
from datetime import datetime
import time

# Import API key
from config import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

columnNames = ["City", "Country","Temperature (F)",
                "Latitude","Longitude","Humidity (%)",
                "Cloudiness (%)", "Wind Speed (mph)"]
cities_df = pd.DataFrame(columns = columnNames)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)




# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    country = citipy.nearest_city(lat_lng[0], lat_lng[1]).country_code
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)
        
        cities_df = cities_df.append({"City": city,"Country": country,},ignore_index=True)
        

# Print the city count to confirm sufficient count
print(len(cities))


url = "http://api.openweathermap.org/data/2.5/weather?"
# Out:
# 627

# %%
cities_df.head()
# Out:
#            City Country Temperature (F) Latitude Longitude Humidity (%)  \
# 0      hamilton      bm             NaN      NaN       NaN          NaN
# 1         yumen      cn             NaN      NaN       NaN          NaN
# 2      saldanha      za             NaN      NaN       NaN          NaN
# 3  punta arenas      cl             NaN      NaN       NaN          NaN
# 4          yaan      cn             NaN      NaN       NaN          NaN
#
#   Cloudiness (%) Wind Speed (mph)
# 0            NaN              NaN
# 1            NaN              NaN
# 2            NaN              NaN
# 3            NaN              NaN
# 4            NaN              NaN

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
data = requests.get("http://api.openweathermap.org/data/2.5/weather?appid=eb5ae928381c706f373119109b250606&units=IMPERIAL&q=atlanta").json()
data
# Out:
# {'coord': {'lon': -84.39, 'lat': 33.75},
#  'weather': [{'id': 803,
#    'main': 'Clouds',
#    'description': 'broken clouds',
#    'icon': '04n'}],
#  'base': 'stations',
#  'main': {'temp': 74.17,
#   'pressure': 1019,
#   'humidity': 64,
#   'temp_min': 71.01,
#   'temp_max': 78.01},
#  'visibility': 16093,
#  'wind': {'speed': 3.36, 'deg': 190},
#  'clouds': {'all': 75},
#  'dt': 1554682341,
#  'sys': {'type': 1,
#   'id': 3335,
#   'message': 0.0101,
#   'country': 'US',
#   'sunrise': 1554635830,
#   'sunset': 1554681712},
#  'id': 4180439,
#  'name': 'Atlanta',
#  'cod': 200}

# %%
print("Ring.. Ring.. Starting Calls")
row_count = 0
set_count = 1
for index, row in cities_df.iterrows():
    target_city = row['City']
    target_url = url + 'appid='+ api_key+'&units=IMPERIAL'+'&q='+target_city
    city_data = requests.get(target_url).json()
    row_count+=1
    
    
    if row_count % 51 == 0:
        set_count += 1
        row_count = 0
        
        
    
    if city_data["cod"] == "404":
        print('City not found. Skipping...')
        
             
    else:
        
        print("Processing Record: "+ str(row_count) + " |<Set " +str(set_count) +">| " + city_data['name'].title()+ ", "+ city_data['sys']['country'])
        cities_df.set_value(index, "Temperature (F)", city_data["main"]["temp"])
        cities_df.set_value(index, "Latitude", city_data["coord"]["lat"])
        cities_df.set_value(index, "Longitude", city_data["coord"]["lon"])
        cities_df.set_value(index, "Humidity (%)", city_data["main"]["humidity"])
        cities_df.set_value(index, "Cloudiness (%)", city_data["clouds"]["all"])
        cities_df.set_value(index, "Wind Speed (mph)", city_data["wind"]["speed"])
        time.sleep(np.random.randint(1.5, 2))
# Out:
# Ring.. Ring.. Starting Calls
# Processing Record: 1 |<Set 1>| Hamilton, CA
# C:\Users\Austin\Anaconda3\lib\site-packages\ipykernel_launcher.py:27: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# C:\Users\Austin\Anaconda3\lib\site-packages\ipykernel_launcher.py:28: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# C:\Users\Austin\Anaconda3\lib\site-packages\ipykernel_launcher.py:29: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# C:\Users\Austin\Anaconda3\lib\site-packages\ipykernel_launcher.py:30: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# C:\Users\Austin\Anaconda3\lib\site-packages\ipykernel_launcher.py:31: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# C:\Users\Austin\Anaconda3\lib\site-packages\ipykernel_launcher.py:32: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# Processing Record: 2 |<Set 1>| Yumen, CN
# Processing Record: 3 |<Set 1>| Saldanha, PT
# Processing Record: 4 |<Set 1>| Punta Arenas, CL
# Processing Record: 5 |<Set 1>| Yaan, NG
# Processing Record: 6 |<Set 1>| Visaginas, LT
# Processing Record: 7 |<Set 1>| Severo-Kurilsk, RU
# Processing Record: 8 |<Set 1>| Loiza, PR
# Processing Record: 9 |<Set 1>| Chenghai, CN
# Processing Record: 10 |<Set 1>| Kerch, UA
# Processing Record: 11 |<Set 1>| Khandyga, RU
# Processing Record: 12 |<Set 1>| Bluff, AU
# Processing Record: 13 |<Set 1>| Yellowknife, CA
# Processing Record: 14 |<Set 1>| Rikitea, PF
# Processing Record: 15 |<Set 1>| Adoni, IN
# Processing Record: 16 |<Set 1>| Eyl, SO
# Processing Record: 17 |<Set 1>| Chuy, UY
# Processing Record: 18 |<Set 1>| Avarua, CK
# Processing Record: 19 |<Set 1>| Sosnovka, RU
# Processing Record: 20 |<Set 1>| Upernavik, GL
# Processing Record: 21 |<Set 1>| Nanortalik, GL
# Processing Record: 22 |<Set 1>| Cape Town, ZA
# Processing Record: 23 |<Set 1>| New Norfolk, AU
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# Processing Record: 28 |<Set 1>| Bambous Virieux, MU
# Processing Record: 29 |<Set 1>| Sao Joao Da Barra, BR
# City not found. Skipping...
# Processing Record: 31 |<Set 1>| Lebu, ET
# City not found. Skipping...
# Processing Record: 33 |<Set 1>| Iqaluit, CA
# Processing Record: 34 |<Set 1>| Mataura, NZ
# Processing Record: 35 |<Set 1>| Ushuaia, AR
# Processing Record: 36 |<Set 1>| Albany, US
# Processing Record: 37 |<Set 1>| Hervey Bay, AU
# Processing Record: 38 |<Set 1>| Ariquemes, BR
# Processing Record: 39 |<Set 1>| Bowen, AU
# Processing Record: 40 |<Set 1>| Leshukonskoye, RU
# City not found. Skipping...
# Processing Record: 42 |<Set 1>| Faanui, PF
# Processing Record: 43 |<Set 1>| Khatanga, RU
# Processing Record: 44 |<Set 1>| Saint-Philippe, CA
# Processing Record: 45 |<Set 1>| Kapaa, US
# Processing Record: 46 |<Set 1>| Clyde River, CA
# City not found. Skipping...
# Processing Record: 48 |<Set 1>| Provideniya, RU
# Processing Record: 49 |<Set 1>| Thompson, CA
# Processing Record: 50 |<Set 1>| Busselton, AU
# Processing Record: 0 |<Set 2>| Luderitz, NA
# Processing Record: 1 |<Set 2>| Opuwo, NA
# Processing Record: 2 |<Set 2>| Enkhuizen, NL
# Processing Record: 3 |<Set 2>| Blagoyevo, RU
# City not found. Skipping...
# Processing Record: 5 |<Set 2>| Maragogi, BR
# Processing Record: 6 |<Set 2>| Mount Isa, AU
# Processing Record: 7 |<Set 2>| Pevek, RU
# Processing Record: 8 |<Set 2>| Vaini, IN
# Processing Record: 9 |<Set 2>| Yanam, IN
# Processing Record: 10 |<Set 2>| Quelimane, MZ
# Processing Record: 11 |<Set 2>| Beringovskiy, RU
# Processing Record: 12 |<Set 2>| Vanavara, RU
# Processing Record: 13 |<Set 2>| Saint Anthony, US
# Processing Record: 14 |<Set 2>| Castro, CL
# Processing Record: 15 |<Set 2>| Hermanus, ZA
# Processing Record: 16 |<Set 2>| Deputatskiy, RU
# City not found. Skipping...
# Processing Record: 18 |<Set 2>| Waddan, LY
# Processing Record: 19 |<Set 2>| Lompoc, US
# Processing Record: 20 |<Set 2>| Kavaratti, IN
# Processing Record: 21 |<Set 2>| Ancud, CL
# Processing Record: 22 |<Set 2>| Juneau, US
# Processing Record: 23 |<Set 2>| Whitehorse, CA
# City not found. Skipping...
# Processing Record: 25 |<Set 2>| Neyvo-Shaytanskiy, RU
# Processing Record: 26 |<Set 2>| Hami, CN
# Processing Record: 27 |<Set 2>| Hobart, AU
# Processing Record: 28 |<Set 2>| Dudinka, RU
# Processing Record: 29 |<Set 2>| Port Alfred, ZA
# Processing Record: 30 |<Set 2>| Mogadishu, SO
# Processing Record: 31 |<Set 2>| Comodoro Rivadavia, AR
# Processing Record: 32 |<Set 2>| Kodiak, US
# Processing Record: 33 |<Set 2>| Pau Dos Ferros, BR
# Processing Record: 34 |<Set 2>| Nikolayevka, RU
# Processing Record: 35 |<Set 2>| Puerto Ayora, EC
# Processing Record: 36 |<Set 2>| Jamestown, AU
# Processing Record: 37 |<Set 2>| Bajram Curri, AL
# Processing Record: 38 |<Set 2>| Kieta, PG
# Processing Record: 39 |<Set 2>| Bredasdorp, ZA
# Processing Record: 40 |<Set 2>| Octeville, FR
# Processing Record: 41 |<Set 2>| Tarrega, ES
# Processing Record: 42 |<Set 2>| Carnarvon, ZA
# Processing Record: 43 |<Set 2>| Chokurdakh, RU
# Processing Record: 44 |<Set 2>| Gursarai, IN
# Processing Record: 45 |<Set 2>| Hilo, US
# Processing Record: 46 |<Set 2>| Port Hardy, CA
# Processing Record: 47 |<Set 2>| Sorland, NO
# Processing Record: 48 |<Set 2>| Dikson, RU
# Processing Record: 49 |<Set 2>| Lorengau, PG
# Processing Record: 50 |<Set 2>| Ahipara, NZ
# Processing Record: 0 |<Set 3>| Butaritari, KI
# Processing Record: 1 |<Set 3>| Muros, ES
# Processing Record: 2 |<Set 3>| Joplin, US
# Processing Record: 3 |<Set 3>| Katsuura, JP
# Processing Record: 4 |<Set 3>| Kanniyakumari, IN
# Processing Record: 5 |<Set 3>| Alice Springs, AU
# Processing Record: 6 |<Set 3>| Santa Cruz, US
# Processing Record: 7 |<Set 3>| Corning, US
# Processing Record: 8 |<Set 3>| The Valley, AI
# Processing Record: 9 |<Set 3>| Natitingou, BJ
# Processing Record: 10 |<Set 3>| Guerrero Negro, MX
# Processing Record: 11 |<Set 3>| Grindavik, IS
# Processing Record: 12 |<Set 3>| Cherskiy, RU
# Processing Record: 13 |<Set 3>| Teruel, ES
# Processing Record: 14 |<Set 3>| Rawlins, US
# Processing Record: 15 |<Set 3>| Muisne, EC
# Processing Record: 16 |<Set 3>| Bilibino, RU
# Processing Record: 17 |<Set 3>| Gazanjyk, TM
# City not found. Skipping...
# Processing Record: 19 |<Set 3>| Waingapu, ID
# Processing Record: 20 |<Set 3>| Kaitangata, NZ
# Processing Record: 21 |<Set 3>| Nikolskoye, RU
# Processing Record: 22 |<Set 3>| Sitka, US
# Processing Record: 23 |<Set 3>| San Lorenzo, PY
# Processing Record: 24 |<Set 3>| Otane, NZ
# Processing Record: 25 |<Set 3>| Ribeira Grande, PT
# Processing Record: 26 |<Set 3>| Ilulissat, GL
# Processing Record: 27 |<Set 3>| Prijepolje, RS
# Processing Record: 28 |<Set 3>| Okhotsk, RU
# Processing Record: 29 |<Set 3>| Starkville, US
# Processing Record: 30 |<Set 3>| Noumea, NC
# Processing Record: 31 |<Set 3>| Tasiilaq, GL
# Processing Record: 32 |<Set 3>| Parana, BR
# Processing Record: 33 |<Set 3>| Gushikawa, JP
# Processing Record: 34 |<Set 3>| Mount Gambier, AU
# Processing Record: 35 |<Set 3>| Kalmunai, LK
# Processing Record: 36 |<Set 3>| Chongwe, ZM
# Processing Record: 37 |<Set 3>| Hun, BE
# Processing Record: 38 |<Set 3>| Moerai, PF
# Processing Record: 39 |<Set 3>| Dombarovskiy, RU
# Processing Record: 40 |<Set 3>| Rocha, UY
# Processing Record: 41 |<Set 3>| Karlstad, SE
# Processing Record: 42 |<Set 3>| Bantacan, PH
# Processing Record: 43 |<Set 3>| Tual, ID
# Processing Record: 44 |<Set 3>| Husavik, CA
# Processing Record: 45 |<Set 3>| Colares, PT
# Processing Record: 46 |<Set 3>| Saravan, AM
# City not found. Skipping...
# City not found. Skipping...
# Processing Record: 49 |<Set 3>| Mega, ET
# Processing Record: 50 |<Set 3>| Tirlyanskiy, RU
# Processing Record: 0 |<Set 4>| Mehamn, NO
# City not found. Skipping...
# Processing Record: 2 |<Set 4>| Arraial Do Cabo, BR
# Processing Record: 3 |<Set 4>| Davila, PH
# Processing Record: 4 |<Set 4>| Tsiroanomandidy, MG
# Processing Record: 5 |<Set 4>| Visby, SE
# Processing Record: 6 |<Set 4>| Bathsheba, BB
# Processing Record: 7 |<Set 4>| Saint-Joseph, FR
# Processing Record: 8 |<Set 4>| Qaanaaq, GL
# Processing Record: 9 |<Set 4>| Hithadhoo, MV
# Processing Record: 10 |<Set 4>| Horsham, AU
# Processing Record: 11 |<Set 4>| Sterling, US
# Processing Record: 12 |<Set 4>| Fougamou, GA
# Processing Record: 13 |<Set 4>| Tilichiki, RU
# Processing Record: 14 |<Set 4>| Petropavlovsk-Kamchatskiy, RU
# Processing Record: 15 |<Set 4>| Riyadh, SA
# Processing Record: 16 |<Set 4>| Vila Franca Do Campo, PT
# Processing Record: 17 |<Set 4>| Sungairaya, ID
# Processing Record: 18 |<Set 4>| Minbu, MM
# Processing Record: 19 |<Set 4>| Saskylakh, RU
# Processing Record: 20 |<Set 4>| Fairbanks, US
# Processing Record: 21 |<Set 4>| Klaksvik, FO
# City not found. Skipping...
# Processing Record: 23 |<Set 4>| Kasongo-Lunda, CD
# Processing Record: 24 |<Set 4>| Barrow, AR
# Processing Record: 25 |<Set 4>| Khurai, IN
# Processing Record: 26 |<Set 4>| Maceio, BR
# City not found. Skipping...
# Processing Record: 28 |<Set 4>| Auki, NG
# Processing Record: 29 |<Set 4>| Salinopolis, BR
# Processing Record: 30 |<Set 4>| Outlook, CA
# City not found. Skipping...
# Processing Record: 32 |<Set 4>| Bolobo, CD
# Processing Record: 33 |<Set 4>| Victoria, BN
# Processing Record: 34 |<Set 4>| Tahe, CN
# Processing Record: 35 |<Set 4>| Vestmannaeyjar, IS
# Processing Record: 36 |<Set 4>| Malindi, KE
# Processing Record: 37 |<Set 4>| Porbandar, IN
# City not found. Skipping...
# Processing Record: 39 |<Set 4>| Narsaq, GL
# Processing Record: 40 |<Set 4>| East London, ZA
# Processing Record: 41 |<Set 4>| Kasamwa, TZ
# Processing Record: 42 |<Set 4>| Tuktoyaktuk, CA
# Processing Record: 43 |<Set 4>| Maunabo, PR
# Processing Record: 44 |<Set 4>| Albox, ES
# Processing Record: 45 |<Set 4>| Kahului, US
# Processing Record: 46 |<Set 4>| Itarema, BR
# Processing Record: 47 |<Set 4>| Jalu, LY
# Processing Record: 48 |<Set 4>| Pedasi, PA
# Processing Record: 49 |<Set 4>| Tutoia, BR
# Processing Record: 50 |<Set 4>| Torbay, CA
# Processing Record: 0 |<Set 5>| Geraldton, CA
# Processing Record: 1 |<Set 5>| Miandrivazo, MG
# Processing Record: 2 |<Set 5>| Burnie, AU
# Processing Record: 3 |<Set 5>| Gat, SN
# Processing Record: 4 |<Set 5>| Idappadi, IN
# City not found. Skipping...
# Processing Record: 6 |<Set 5>| Norman Wells, CA
# Processing Record: 7 |<Set 5>| Werda, DE
# Processing Record: 8 |<Set 5>| Aitape, PG
# Processing Record: 9 |<Set 5>| Hasaki, JP
# Processing Record: 10 |<Set 5>| Estacion Coahuila, MX
# Processing Record: 11 |<Set 5>| Heiligenhafen, DE
# Processing Record: 12 |<Set 5>| Teguldet, RU
# Processing Record: 13 |<Set 5>| Sinnamary, GF
# Processing Record: 14 |<Set 5>| Tuatapere, NZ
# Processing Record: 15 |<Set 5>| Atuona, PF
# Processing Record: 16 |<Set 5>| Namatanai, PG
# Processing Record: 17 |<Set 5>| Marsh Harbour, BS
# Processing Record: 18 |<Set 5>| Egvekinot, RU
# Processing Record: 19 |<Set 5>| Havoysund, NO
# City not found. Skipping...
# Processing Record: 21 |<Set 5>| Burley, US
# City not found. Skipping...
# Processing Record: 23 |<Set 5>| Rorvik, NO
# Processing Record: 24 |<Set 5>| Alofi, NU
# Processing Record: 25 |<Set 5>| Miraflores, CO
# Processing Record: 26 |<Set 5>| Padang, ID
# Processing Record: 27 |<Set 5>| Balkanabat, TM
# Processing Record: 28 |<Set 5>| Laguna, MX
# Processing Record: 29 |<Set 5>| Bezhetsk, RU
# Processing Record: 30 |<Set 5>| Aktau, KZ
# Processing Record: 31 |<Set 5>| Gualeguay, AR
# City not found. Skipping...
# Processing Record: 33 |<Set 5>| Qaqortoq, GL
# Processing Record: 34 |<Set 5>| Balotra, IN
# Processing Record: 35 |<Set 5>| Mbini, GQ
# Processing Record: 36 |<Set 5>| Manacapuru, BR
# Processing Record: 37 |<Set 5>| Port-Cartier, CA
# Processing Record: 38 |<Set 5>| Atar, MR
# Processing Record: 39 |<Set 5>| Lianran, CN
# Processing Record: 40 |<Set 5>| Lagoa, PT
# Processing Record: 41 |<Set 5>| Pelym, RU
# Processing Record: 42 |<Set 5>| Hambantota, LK
# Processing Record: 43 |<Set 5>| Ekuvukeni, ZA
# Processing Record: 44 |<Set 5>| Longyearbyen, NO
# City not found. Skipping...
# Processing Record: 46 |<Set 5>| Lucapa, AO
# Processing Record: 47 |<Set 5>| Isabela, PH
# City not found. Skipping...
# Processing Record: 49 |<Set 5>| Souillac, FR
# Processing Record: 50 |<Set 5>| Shuangcheng, CN
# Processing Record: 0 |<Set 6>| Chornobay, UA
# Processing Record: 1 |<Set 6>| Sovetsk, RU
# Processing Record: 2 |<Set 6>| Marsa Matruh, EG
# Processing Record: 3 |<Set 6>| Raudeberg, NO
# Processing Record: 4 |<Set 6>| San Cristobal, EC
# Processing Record: 5 |<Set 6>| Esperance, TT
# Processing Record: 6 |<Set 6>| Muyezerskiy, RU
# Processing Record: 7 |<Set 6>| Serpa, PT
# Processing Record: 8 |<Set 6>| Bonwapitse, BW
# Processing Record: 9 |<Set 6>| Loukhi, RU
# Processing Record: 10 |<Set 6>| Port Macquarie, AU
# Processing Record: 11 |<Set 6>| Barabai, ID
# Processing Record: 12 |<Set 6>| Yagodnoye, RU
# City not found. Skipping...
# Processing Record: 14 |<Set 6>| Kavieng, PG
# Processing Record: 15 |<Set 6>| Buala, SB
# Processing Record: 16 |<Set 6>| Camacha, PT
# Processing Record: 17 |<Set 6>| Talcahuano, CL
# Processing Record: 18 |<Set 6>| Valparaiso, US
# Processing Record: 19 |<Set 6>| Road Town, VG
# Processing Record: 20 |<Set 6>| Aklavik, CA
# Processing Record: 21 |<Set 6>| Elizabeth City, US
# City not found. Skipping...
# Processing Record: 23 |<Set 6>| Honiara, SB
# Processing Record: 24 |<Set 6>| Tigil, RU
# Processing Record: 25 |<Set 6>| Karpogory, RU
# Processing Record: 26 |<Set 6>| Christchurch, NZ
# Processing Record: 27 |<Set 6>| Mar Del Plata, AR
# Processing Record: 28 |<Set 6>| Sokyryany, UA
# Processing Record: 29 |<Set 6>| Trairi, BR
# Processing Record: 30 |<Set 6>| Verkhnevilyuysk, RU
# Processing Record: 31 |<Set 6>| Pisco, PE
# Processing Record: 32 |<Set 6>| Puri, ID
# Processing Record: 33 |<Set 6>| Westport, IE
# Processing Record: 34 |<Set 6>| Cidreira, BR
# Processing Record: 35 |<Set 6>| Yeppoon, AU
# City not found. Skipping...
# Processing Record: 37 |<Set 6>| Port Elizabeth, US
# Processing Record: 38 |<Set 6>| Golden, CA
# Processing Record: 39 |<Set 6>| Sur, OM
# Processing Record: 40 |<Set 6>| Ponta Do Sol, BR
# Processing Record: 41 |<Set 6>| San Juan, PR
# Processing Record: 42 |<Set 6>| Severo-Yeniseyskiy, RU
# Processing Record: 43 |<Set 6>| Mitchell, US
# Processing Record: 44 |<Set 6>| Cockburn Town, TC
# Processing Record: 45 |<Set 6>| Kouango, CF
# Processing Record: 46 |<Set 6>| Rapid Valley, US
# Processing Record: 47 |<Set 6>| Zhigansk, RU
# Processing Record: 48 |<Set 6>| Qinzhou, CN
# Processing Record: 49 |<Set 6>| Siguiri, GN
# Processing Record: 50 |<Set 6>| Salem, US
# Processing Record: 0 |<Set 7>| Walvis Bay, NA
# Processing Record: 1 |<Set 7>| Constitucion, MX
# Processing Record: 2 |<Set 7>| Sao Filipe, CV
# Processing Record: 3 |<Set 7>| Aykhal, RU
# Processing Record: 4 |<Set 7>| Alexandria, US
# Processing Record: 5 |<Set 7>| Zverinogolovskoye, RU
# Processing Record: 6 |<Set 7>| Coquimbo, CL
# Processing Record: 7 |<Set 7>| Komsomolskiy, RU
# Processing Record: 8 |<Set 7>| Necochea, AR
# Processing Record: 9 |<Set 7>| Vardo, US
# Processing Record: 10 |<Set 7>| Cabra, ES
# Processing Record: 11 |<Set 7>| Palencia, ES
# Processing Record: 12 |<Set 7>| Coihaique, CL
# Processing Record: 13 |<Set 7>| Medea, DZ
# Processing Record: 14 |<Set 7>| Cabo San Lucas, MX
# Processing Record: 15 |<Set 7>| Toccoa, US
# Processing Record: 16 |<Set 7>| Dumai, ID
# Processing Record: 17 |<Set 7>| Pareora, NZ
# Processing Record: 18 |<Set 7>| Leningradskiy, RU
# Processing Record: 19 |<Set 7>| Paita, PE
# Processing Record: 20 |<Set 7>| Uray, RU
# Processing Record: 21 |<Set 7>| Bartica, GY
# City not found. Skipping...
# Processing Record: 23 |<Set 7>| Menongue, AO
# Processing Record: 24 |<Set 7>| Halifax, CA
# Processing Record: 25 |<Set 7>| Bin Qirdan, TN
# Processing Record: 26 |<Set 7>| Kaeo, NZ
# Processing Record: 27 |<Set 7>| Matamoros, US
# Processing Record: 28 |<Set 7>| Griffith, AU
# Processing Record: 29 |<Set 7>| Codrington, AU
# Processing Record: 30 |<Set 7>| Moramanga, MG
# Processing Record: 31 |<Set 7>| Sao Felix Do Xingu, BR
# Processing Record: 32 |<Set 7>| Maturin, VE
# Processing Record: 33 |<Set 7>| Sjovegan, NO
# Processing Record: 34 |<Set 7>| Christiana, ZA
# Processing Record: 35 |<Set 7>| Timra, SE
# Processing Record: 36 |<Set 7>| Sars, RU
# Processing Record: 37 |<Set 7>| Shimoda, JP
# Processing Record: 38 |<Set 7>| Hailar, CN
# City not found. Skipping...
# Processing Record: 40 |<Set 7>| Vigia Del Fuerte, CO
# Processing Record: 41 |<Set 7>| Kremasti, GR
# City not found. Skipping...
# Processing Record: 43 |<Set 7>| Atascocita, US
# City not found. Skipping...
# Processing Record: 45 |<Set 7>| Tianpeng, CN
# Processing Record: 46 |<Set 7>| Araxa, BR
# Processing Record: 47 |<Set 7>| Airai, TL
# Processing Record: 48 |<Set 7>| Yuryev-Polskiy, RU
# City not found. Skipping...
# Processing Record: 50 |<Set 7>| Shubarkuduk, KZ
# Processing Record: 0 |<Set 8>| Jiwani, PK
# Processing Record: 1 |<Set 8>| Saint George, GR
# Processing Record: 2 |<Set 8>| Indramayu, ID
# Processing Record: 3 |<Set 8>| Storforshei, NO
# Processing Record: 4 |<Set 8>| Rehoboth, NA
# Processing Record: 5 |<Set 8>| Estelle, US
# Processing Record: 6 |<Set 8>| Nagato, JP
# Processing Record: 7 |<Set 8>| Batagay-Alyta, RU
# Processing Record: 8 |<Set 8>| Samarai, PG
# Processing Record: 9 |<Set 8>| Yushan, CN
# Processing Record: 10 |<Set 8>| Bilma, NE
# Processing Record: 11 |<Set 8>| Nishihara, JP
# Processing Record: 12 |<Set 8>| Sebinkarahisar, TR
# City not found. Skipping...
# Processing Record: 14 |<Set 8>| Karlskoga, SE
# Processing Record: 15 |<Set 8>| Praia, BR
# Processing Record: 16 |<Set 8>| Jaicos, BR
# Processing Record: 17 |<Set 8>| Kharp, RU
# Processing Record: 18 |<Set 8>| Taveta, TZ
# Processing Record: 19 |<Set 8>| Vao, EE
# Processing Record: 20 |<Set 8>| Southend-On-Sea, GB
# Processing Record: 21 |<Set 8>| Fuerte Olimpo, BR
# City not found. Skipping...
# Processing Record: 23 |<Set 8>| San Patricio, PY
# Processing Record: 24 |<Set 8>| Bassila, BJ
# Processing Record: 25 |<Set 8>| Baykit, RU
# Processing Record: 26 |<Set 8>| Lavrentiya, RU
# Processing Record: 27 |<Set 8>| Fare, PF
# Processing Record: 28 |<Set 8>| Georgetown, GY
# Processing Record: 29 |<Set 8>| Zhangjiakou, CN
# Processing Record: 30 |<Set 8>| Port Blair, IN
# Processing Record: 31 |<Set 8>| Bosaso, SO
# Processing Record: 32 |<Set 8>| Cangucu, BR
# Processing Record: 33 |<Set 8>| Santa Barbara, US
# Processing Record: 34 |<Set 8>| Izumo, JP
# Processing Record: 35 |<Set 8>| Portland, US
# Processing Record: 36 |<Set 8>| Manoel Urbano, BR
# City not found. Skipping...
# Processing Record: 38 |<Set 8>| Linxi, CN
# Processing Record: 39 |<Set 8>| Puerto Leguizamo, CO
# Processing Record: 40 |<Set 8>| Broome, GB
# Processing Record: 41 |<Set 8>| Zhezkazgan, KZ
# Processing Record: 42 |<Set 8>| Mahebourg, MU
# Processing Record: 43 |<Set 8>| Miri, NG
# Processing Record: 44 |<Set 8>| Bandarbeyla, SO
# Processing Record: 45 |<Set 8>| Black River, JM
# Processing Record: 46 |<Set 8>| Bayshore Gardens, US
# Processing Record: 47 |<Set 8>| Chimoio, MZ
# Processing Record: 48 |<Set 8>| Male, UA
# Processing Record: 49 |<Set 8>| Paamiut, GL
# Processing Record: 50 |<Set 8>| Ostrovnoy, RU
# Processing Record: 0 |<Set 9>| Charters Towers, AU
# Processing Record: 1 |<Set 9>| Rybnoye, RU
# Processing Record: 2 |<Set 9>| Port Augusta, AU
# Processing Record: 3 |<Set 9>| Kruisfontein, ZA
# Processing Record: 4 |<Set 9>| Toguchin, RU
# Processing Record: 5 |<Set 9>| Moen, NO
# Processing Record: 6 |<Set 9>| Tongchuan, CN
# Processing Record: 7 |<Set 9>| Novoagansk, RU
# Processing Record: 8 |<Set 9>| Russell, AR
# Processing Record: 9 |<Set 9>| Adre, TD
# Processing Record: 10 |<Set 9>| Winslow, GB
# Processing Record: 11 |<Set 9>| Dicabisagan, PH
# Processing Record: 12 |<Set 9>| Naze, NG
# Processing Record: 13 |<Set 9>| Grand Gaube, MU
# Processing Record: 14 |<Set 9>| Roebourne, AU
# City not found. Skipping...
# Processing Record: 16 |<Set 9>| Salalah, OM
# Processing Record: 17 |<Set 9>| Piacabucu, BR
# Processing Record: 18 |<Set 9>| Shingu, JP
# Processing Record: 19 |<Set 9>| Bethel, US
# Processing Record: 20 |<Set 9>| Saint-Georges, CA
# Processing Record: 21 |<Set 9>| Mackenzie, CA
# Processing Record: 22 |<Set 9>| Santa Cruz De La Palma, ES
# Processing Record: 23 |<Set 9>| La Ronge, CA
# Processing Record: 24 |<Set 9>| Gudur, IN
# Processing Record: 25 |<Set 9>| Kerchevskiy, RU
# Processing Record: 26 |<Set 9>| Boquira, BR
# Processing Record: 27 |<Set 9>| Yar-Sale, RU
# Processing Record: 28 |<Set 9>| Prince Rupert, CA
# Processing Record: 29 |<Set 9>| Edeia, BR
# Processing Record: 30 |<Set 9>| Rietavas, LT
# Processing Record: 31 |<Set 9>| Isla Vista, US
# Processing Record: 32 |<Set 9>| Sturgis, US
# Processing Record: 33 |<Set 9>| Aswan, EG
# Processing Record: 34 |<Set 9>| Killybegs, IE
# Processing Record: 35 |<Set 9>| Quatre Cocos, MU
# Processing Record: 36 |<Set 9>| Taunggyi, MM
# Processing Record: 37 |<Set 9>| Petropavlovka, RU
# City not found. Skipping...
# Processing Record: 39 |<Set 9>| Puerto Escondido, MX
# Processing Record: 40 |<Set 9>| Hammerfest, NO
# Processing Record: 41 |<Set 9>| Ventspils, LV
# Processing Record: 42 |<Set 9>| Pitimbu, BR
# Processing Record: 43 |<Set 9>| Marabba, SD
# Processing Record: 44 |<Set 9>| Hirara, JP
# Processing Record: 45 |<Set 9>| Cocorit, MX
# Processing Record: 46 |<Set 9>| Oksovskiy, RU
# Processing Record: 47 |<Set 9>| Ust-Ilimsk, RU
# Processing Record: 48 |<Set 9>| Vaitape, PF
# Processing Record: 49 |<Set 9>| Okha, RU
# Processing Record: 50 |<Set 9>| Callaguip, PH
# Processing Record: 0 |<Set 10>| Yulara, AU
# Processing Record: 1 |<Set 10>| Lima, PE
# Processing Record: 2 |<Set 10>| Vallenar, CL
# Processing Record: 3 |<Set 10>| Lodja, CD
# Processing Record: 4 |<Set 10>| Bonthe, SL
# City not found. Skipping...
# Processing Record: 6 |<Set 10>| San Quintin, PH
# Processing Record: 7 |<Set 10>| Fortuna, ES
# Processing Record: 8 |<Set 10>| Darhan, MN
# City not found. Skipping...
# Processing Record: 10 |<Set 10>| Mrakovo, RU
# Processing Record: 11 |<Set 10>| Quimper, FR
# City not found. Skipping...
# Processing Record: 13 |<Set 10>| Wajima, JP
# Processing Record: 14 |<Set 10>| Shebalino, RU
# Processing Record: 15 |<Set 10>| Touros, BR
# Processing Record: 16 |<Set 10>| Nouadhibou, MR
# Processing Record: 17 |<Set 10>| Kurayoshi, JP
# City not found. Skipping...
# Processing Record: 19 |<Set 10>| Meulaboh, ID
# Processing Record: 20 |<Set 10>| Saint-Francois, FR
# City not found. Skipping...
# Processing Record: 22 |<Set 10>| Muravlenko, RU
# Processing Record: 23 |<Set 10>| Sri Aman, MY
# City not found. Skipping...
# Processing Record: 25 |<Set 10>| Tautira, PF
# Processing Record: 26 |<Set 10>| Mersing, MY
# Processing Record: 27 |<Set 10>| Zhuji, CN
# Processing Record: 28 |<Set 10>| Henties Bay, NA
# Processing Record: 29 |<Set 10>| Vrangel, RU
# City not found. Skipping...
# Processing Record: 31 |<Set 10>| Haines Junction, CA
# Processing Record: 32 |<Set 10>| Bereda, ES
# Processing Record: 33 |<Set 10>| Mahenge, TZ
# Processing Record: 34 |<Set 10>| Kokkola, FI
# Processing Record: 35 |<Set 10>| Goderich, CA
# Processing Record: 36 |<Set 10>| Luau, CD
# City not found. Skipping...
# Processing Record: 38 |<Set 10>| Khargone, IN
# Processing Record: 39 |<Set 10>| Limbang, BN
# Processing Record: 40 |<Set 10>| Diffa, NE
# Processing Record: 41 |<Set 10>| Kantang, TH
# Processing Record: 42 |<Set 10>| Tamasane, BW
# City not found. Skipping...
# Processing Record: 44 |<Set 10>| Koplik, AL
# Processing Record: 45 |<Set 10>| Romitan, UZ
# Processing Record: 46 |<Set 10>| Tripoli, GR
# Processing Record: 47 |<Set 10>| La Esperanza, HN
# Processing Record: 48 |<Set 10>| Nome, US
# Processing Record: 49 |<Set 10>| Sabya, YE
# Processing Record: 50 |<Set 10>| Saint-Pierre, FR
# Processing Record: 0 |<Set 11>| Aligudarz, IR
# Processing Record: 1 |<Set 11>| Tarut, SA
# Processing Record: 2 |<Set 11>| Kasongo, CD
# Processing Record: 3 |<Set 11>| Penzance, GB
# Processing Record: 4 |<Set 11>| Iberia, PE
# Processing Record: 5 |<Set 11>| Uhlove, UA
# Processing Record: 6 |<Set 11>| Saint-Jean-De-Luz, FR
# Processing Record: 7 |<Set 11>| Lubao, PH
# Processing Record: 8 |<Set 11>| Yatou, CM
# Processing Record: 9 |<Set 11>| Havre-Saint-Pierre, CA
# Processing Record: 10 |<Set 11>| Lata, IN
# Processing Record: 11 |<Set 11>| Beloha, MG
# Processing Record: 12 |<Set 11>| Nago, IT
# Processing Record: 13 |<Set 11>| Kirensk, RU
# Processing Record: 14 |<Set 11>| West Bay, GB
# Processing Record: 15 |<Set 11>| Palu, ID
# Processing Record: 16 |<Set 11>| Dauphin, CA
# Processing Record: 17 |<Set 11>| Port Hedland, AU
# Processing Record: 18 |<Set 11>| Jacareacanga, BR
# Processing Record: 19 |<Set 11>| Banda Aceh, ID
# Processing Record: 20 |<Set 11>| Sarh, TD
# Processing Record: 21 |<Set 11>| Arlit, NE
# Processing Record: 22 |<Set 11>| Ketchikan, US
# Processing Record: 23 |<Set 11>| Sovetskaya, RU
# Processing Record: 24 |<Set 11>| Ixtapa, MX
# Processing Record: 25 |<Set 11>| Bandipur, IN
# City not found. Skipping...
# Processing Record: 27 |<Set 11>| Half Moon Bay, US
# Processing Record: 28 |<Set 11>| Tomatlan, MX
# Processing Record: 29 |<Set 11>| Mata, CU
# Processing Record: 30 |<Set 11>| Sibolga, ID
# City not found. Skipping...
# Processing Record: 32 |<Set 11>| Awbari, LY
# Processing Record: 33 |<Set 11>| Kailahun, SL
# Processing Record: 34 |<Set 11>| Teguise, ES
# Processing Record: 35 |<Set 11>| Feldkirchen, DE
# Processing Record: 36 |<Set 11>| Marzuq, YE
# Processing Record: 37 |<Set 11>| Sinjar, SY
# Processing Record: 38 |<Set 11>| Los Llanos De Aridane, ES
# Processing Record: 39 |<Set 11>| Santiago Del Estero, AR
# Processing Record: 40 |<Set 11>| Ghanzi, BW
# Processing Record: 41 |<Set 11>| Bjornevatn, NO
# Processing Record: 42 |<Set 11>| Staryy Nadym, RU
# Processing Record: 43 |<Set 11>| Albi, FR
# City not found. Skipping...
# Processing Record: 45 |<Set 11>| Kargasok, RU
# Processing Record: 46 |<Set 11>| Prachuap Khiri Khan, TH
# Processing Record: 47 |<Set 11>| Lasa, CY
# Processing Record: 48 |<Set 11>| Katherine, AU
# Processing Record: 49 |<Set 11>| Kedrovyy, RU
# Processing Record: 50 |<Set 11>| Mweka, CD
# Processing Record: 0 |<Set 12>| Ambilobe, MG
# Processing Record: 1 |<Set 12>| Nyurba, RU
# Processing Record: 2 |<Set 12>| Cruzeiro Do Sul, BR
# Processing Record: 3 |<Set 12>| Omsukchan, RU
# Processing Record: 4 |<Set 12>| Tingo Maria, PE
# Processing Record: 5 |<Set 12>| Teyateyaneng, LS
# Processing Record: 6 |<Set 12>| Vila Do Maio, CV
# Processing Record: 7 |<Set 12>| Lazaro Cardenas, MX
# Processing Record: 8 |<Set 12>| Zhiryatino, RU
# City not found. Skipping...
# Processing Record: 10 |<Set 12>| Aden, YE
# Processing Record: 11 |<Set 12>| Lewistown, US
# Processing Record: 12 |<Set 12>| Rancho Palos Verdes, US
# Processing Record: 13 |<Set 12>| Tieli, CN
# Processing Record: 14 |<Set 12>| Parabel, RU
# Processing Record: 15 |<Set 12>| Cap Malheureux, MU
# Processing Record: 16 |<Set 12>| Chastyye, RU
# City not found. Skipping...
# City not found. Skipping...
# Processing Record: 19 |<Set 12>| Ziro, IN
# Processing Record: 20 |<Set 12>| Ust-Tarka, RU
# Processing Record: 21 |<Set 12>| Proddatur, IN
# Processing Record: 22 |<Set 12>| Merauke, ID
# City not found. Skipping...
# Processing Record: 24 |<Set 12>| Linxia, CN
# Processing Record: 25 |<Set 12>| Nadym, RU
# Processing Record: 26 |<Set 12>| Rio Gallegos, AR
# Processing Record: 27 |<Set 12>| Progreso, UY
# Processing Record: 28 |<Set 12>| Kudahuvadhoo, MV
# Processing Record: 29 |<Set 12>| Draguignan, FR
# Processing Record: 30 |<Set 12>| Zhanakorgan, KZ
# Processing Record: 31 |<Set 12>| Channel-Port Aux Basques, CA
# Processing Record: 32 |<Set 12>| Luganville, VU
# Processing Record: 33 |<Set 12>| Aleksandrov, RU
# Processing Record: 34 |<Set 12>| Ulaanbaatar, MN
# Processing Record: 35 |<Set 12>| Samut Prakan, TH
# Processing Record: 36 |<Set 12>| Morant Bay, JM
# Processing Record: 37 |<Set 12>| Challapata, BO
# Processing Record: 38 |<Set 12>| Haapiti, PF
# Processing Record: 39 |<Set 12>| Bambanglipuro, ID
# Processing Record: 40 |<Set 12>| Kongolo, CD
# Processing Record: 41 |<Set 12>| Namibe, AO
# City not found. Skipping...
# Processing Record: 43 |<Set 12>| Morondava, MG
# Processing Record: 44 |<Set 12>| Kemin, KG
# Processing Record: 45 |<Set 12>| Mayumba, GA
# Processing Record: 46 |<Set 12>| Tarko-Sale, RU
# City not found. Skipping...
# City not found. Skipping...
# Processing Record: 49 |<Set 12>| Les Escoumins, CA
# Processing Record: 50 |<Set 12>| Hofn, IS
# City not found. Skipping...
# Processing Record: 1 |<Set 13>| College, US
# Processing Record: 2 |<Set 13>| Cayenne, GF
# Processing Record: 3 |<Set 13>| Tiksi, RU
# Processing Record: 4 |<Set 13>| Ornskoldsvik, SE
# Processing Record: 5 |<Set 13>| Taoudenni, ML
# Processing Record: 6 |<Set 13>| Inhambane, MZ
# City not found. Skipping...
# Processing Record: 8 |<Set 13>| Marystown, CA
# City not found. Skipping...
# City not found. Skipping...
# Processing Record: 11 |<Set 13>| Sao Luis Do Quitunde, BR
# Processing Record: 12 |<Set 13>| Shu, KZ
# City not found. Skipping...
# Processing Record: 14 |<Set 13>| Pacifica, US
# Processing Record: 15 |<Set 13>| Karratha, AU

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
cities_df.dropna(inplace=True)
cities_df.count()
# Out:
# City                565
# Country             565
# Temperature (F)     565
# Latitude            565
# Longitude           565
# Humidity (%)        565
# Cloudiness (%)      565
# Wind Speed (mph)    565
# dtype: int64

# %%
cities_df.to_csv(r'..\outputs\dataframe.csv')
cities_df.head()
# Out:
#            City Country Temperature (F) Latitude Longitude Humidity (%)  \
# 0      hamilton      bm           48.58    43.26    -79.87           71
# 1         yumen      cn           40.44    40.29     97.04           69
# 2      saldanha      za           47.82    41.42     -6.55           97
# 3  punta arenas      cl           44.26   -53.16    -70.91           70
# 4          yaan      cn           80.76     7.38      8.57           78
#
#   Cloudiness (%) Wind Speed (mph)
# 0             75            12.75
# 1             88            14.79
# 2             92             8.75
# 3             75             9.17
# 4             36             7.29

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
plt.scatter(cities_df["Latitude"],
           cities_df["Temperature (F)"], c=cities_df["Temperature (F)"],
           edgecolor="silver", linewidths = 1.5, marker="8",
           cmap='plasma', alpha=0.75, label="City")

plt.style.use('seaborn')
plt.title(f"City Latitude vs. Max Temperature {datetime.now().strftime('%m/%d/%Y')}")
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)
plt.xlim([-80, 100])
plt.ylim([-60, 120])
plt.savefig("../outputs/Lat_Temp.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
plt.scatter(cities_df["Latitude"],
           cities_df["Humidity (%)"], c=cities_df["Humidity (%)"],
           edgecolor="silver", linewidths = 1.15, marker="8",
           cmap='GnBu', alpha=0.75, label="City")

plt.style.use('seaborn')
plt.title(f"City Latitude vs Humidity (%) {datetime.now().strftime('%m/%d/%Y')}")
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)
plt.xlim([-80, 100])
plt.ylim([-5, 125])
plt.savefig("../outputs/Lat_Humid.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
plt.scatter(cities_df["Latitude"],
           cities_df["Cloudiness (%)"], c=cities_df["Cloudiness (%)"],
           edgecolor="silver", linewidths = 1.5, marker="8",
           cmap='bone_r', alpha=0.75, label="City")

plt.style.use('seaborn')
plt.title(f"City Latitude vs Cloudiness (%) {datetime.now().strftime('%m/%d/%Y')}")
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)
plt.xlim([-80, 100])
plt.ylim([-5, 125])
plt.savefig("../outputs/Lat_cloud.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
plt.scatter(cities_df["Latitude"],
           cities_df["Cloudiness (%)"], c=cities_df["Cloudiness (%)"],
           edgecolor="silver", linewidths = 1.5, marker="8",
           cmap='bone_r', alpha=0.75, label="City")

plt.style.use('seaborn')
plt.title(f"City Latitude vs Wind Speed (mph) {datetime.now().strftime('%m/%d/%Y')}")
plt.ylabel("Wind Speed (mph))")
plt.xlabel("Latitude")
plt.grid(True)
plt.xlim([-80, 100])
plt.ylim([-5, 125])
plt.savefig("../outputs/Lat_windspd.png")
plt.show()
