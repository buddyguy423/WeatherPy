# %% [markdown]
# # WeatherPy
# ----
#
# ### Analysis
# * As expected, the weather becomes significantly warmer as one approaches the equator (0 Deg. Latitude). More interestingly, however, is the fact that the southern hemisphere tends to be warmer this time of year than the northern hemisphere. This may be due to the tilt of the earth.
# * There is no strong relationship between latitude and cloudiness. However, it is interesting to see that a strong band of cities sits at 0, 80, and 100% cloudiness.
# * There is no strong relationship between latitude and wind speed. However, in northern hemispheres there is a flurry of cities with over 20 mph of wind.
#
# ---
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from datetime import datetime

# Import API key
from config import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

columnNames = ["City", "Country","Temperature (F)",
                "Latitude","Longitude","Humidity (%)",
                "Cloudiness (%)", "Wind Speed (mph)"]
cities_df = pd.DataFrame(columns = columnNames)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)




# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    country = citipy.nearest_city(lat_lng[0], lat_lng[1]).country_code
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)
        
        cities_df = cities_df.append({"City": city,"Country": country,},ignore_index=True)
        

# Print the city count to confirm sufficient count
print(len(cities))


url = "http://api.openweathermap.org/data/2.5/weather?"
# Out:
# 596

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
print("Ring.. Ring.. Starting Calls")
row_count = 0
set_count = 1
for index, row in cities_df.iterrows():
    target_city = row['City']
    target_url = url + 'appid='+ api_key+'&units=IMPERIAL'+'&q='+target_city
    city_data = requests.get(target_url).json()
    row_count+=1
    
    
    if row_count % 51 == 0:
        set_count += 1
        row_count = 0
        
        
    
    if city_data["cod"] == "404":
        print('City not found. Skipping...')
        
             
    else:
        
        print("Processing Record: "+ str(row_count) + " |<Set " +str(set_count) +">| " + city_data['name'].title()+ ", "+ city_data['sys']['country'])
        cities_df.set_value(index, "Temperature (F)", city_data["main"]["temp"])
        cities_df.set_value(index, "Latitude", city_data["coord"]["lat"])
        cities_df.set_value(index, "Longitude", city_data["coord"]["lon"])
        cities_df.set_value(index, "Humidity (%)", city_data["main"]["humidity"])
        cities_df.set_value(index, "Cloudiness (%)", city_data["clouds"]["all"])
        cities_df.set_value(index, "Wind Speed (mph)", city_data["wind"]["speed"])
        
        
        
        
        
        
        ## I didnt want to make it seem like suspicious traffic
        time.sleep(np.random.randint(1.5, 2))
# Out:
# Ring.. Ring.. Starting Calls
# Processing Record: 1 |<Set 1>| Roald, NO
# C:\Users\Austin\Anaconda3\lib\site-packages\ipykernel_launcher.py:24: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# C:\Users\Austin\Anaconda3\lib\site-packages\ipykernel_launcher.py:25: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# C:\Users\Austin\Anaconda3\lib\site-packages\ipykernel_launcher.py:26: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# C:\Users\Austin\Anaconda3\lib\site-packages\ipykernel_launcher.py:27: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# C:\Users\Austin\Anaconda3\lib\site-packages\ipykernel_launcher.py:28: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# C:\Users\Austin\Anaconda3\lib\site-packages\ipykernel_launcher.py:29: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# Processing Record: 2 |<Set 1>| Hermanus, ZA
# Processing Record: 3 |<Set 1>| Clyde River, CA
# Processing Record: 4 |<Set 1>| Bluff, AU
# Processing Record: 5 |<Set 1>| Tuktoyaktuk, CA
# Processing Record: 6 |<Set 1>| Dunedin, NZ
# Processing Record: 7 |<Set 1>| Hami, CN
# Processing Record: 8 |<Set 1>| Isla Vista, US
# City not found. Skipping...
# Processing Record: 10 |<Set 1>| Baruun-Urt, MN
# Processing Record: 11 |<Set 1>| Natal, BR
# Processing Record: 12 |<Set 1>| Mataura, NZ
# City not found. Skipping...
# Processing Record: 14 |<Set 1>| Solnechnyy, RU
# Processing Record: 15 |<Set 1>| Castro, CL
# Processing Record: 16 |<Set 1>| Pimenta Bueno, BR
# Processing Record: 17 |<Set 1>| Geraldton, CA
# Processing Record: 18 |<Set 1>| Purpe, RU
# Processing Record: 19 |<Set 1>| Yerbogachen, RU
# Processing Record: 20 |<Set 1>| Rikitea, PF
# Processing Record: 21 |<Set 1>| Binzhou, CN
# Processing Record: 22 |<Set 1>| Lensk, RU
# Processing Record: 23 |<Set 1>| Dingle, PH
# Processing Record: 24 |<Set 1>| Hithadhoo, MV
# Processing Record: 25 |<Set 1>| Lethem, GY
# Processing Record: 26 |<Set 1>| Garden City, US
# Processing Record: 27 |<Set 1>| Chokurdakh, RU
# Processing Record: 28 |<Set 1>| Hilo, US
# Processing Record: 29 |<Set 1>| Mehamn, NO
# City not found. Skipping...
# Processing Record: 31 |<Set 1>| Wyndham, GB
# City not found. Skipping...
# Processing Record: 33 |<Set 1>| Kapaa, US
# Processing Record: 34 |<Set 1>| Tasiilaq, GL
# Processing Record: 35 |<Set 1>| Atambua, ID
# City not found. Skipping...
# Processing Record: 37 |<Set 1>| Ahipara, NZ
# Processing Record: 38 |<Set 1>| Jamestown, AU
# Processing Record: 39 |<Set 1>| Atuona, PF
# Processing Record: 40 |<Set 1>| Ushuaia, AR
# Processing Record: 41 |<Set 1>| Hobart, AU
# Processing Record: 42 |<Set 1>| Wolgast, DE
# Processing Record: 43 |<Set 1>| Kruisfontein, ZA
# Processing Record: 44 |<Set 1>| Torbay, CA
# Processing Record: 45 |<Set 1>| Khatanga, RU
# Processing Record: 46 |<Set 1>| Samtredia, GE
# Processing Record: 47 |<Set 1>| Artigas, BR
# Processing Record: 48 |<Set 1>| Puerto Ayora, EC
# Processing Record: 49 |<Set 1>| Albany, US
# Processing Record: 50 |<Set 1>| Avera, US
# City not found. Skipping...
# City not found. Skipping...
# Processing Record: 2 |<Set 2>| Naryan-Mar, RU
# Processing Record: 3 |<Set 2>| Kieta, PG
# Processing Record: 4 |<Set 2>| Cherskiy, RU
# Processing Record: 5 |<Set 2>| San Quintin, PH
# Processing Record: 6 |<Set 2>| Bredasdorp, ZA
# Processing Record: 7 |<Set 2>| New Norfolk, AU
# Processing Record: 8 |<Set 2>| Mahebourg, MU
# Processing Record: 9 |<Set 2>| Kodiak, US
# Processing Record: 10 |<Set 2>| Carnarvon, ZA
# Processing Record: 11 |<Set 2>| Punta Arenas, CL
# Processing Record: 12 |<Set 2>| Kenai, US
# Processing Record: 13 |<Set 2>| Iqaluit, CA
# Processing Record: 14 |<Set 2>| Georgetown, GY
# Processing Record: 15 |<Set 2>| Upernavik, GL
# Processing Record: 16 |<Set 2>| Kitab, UZ
# Processing Record: 17 |<Set 2>| Vaini, IN
# Processing Record: 18 |<Set 2>| Manthani, IN
# Processing Record: 19 |<Set 2>| Busselton, AU
# Processing Record: 20 |<Set 2>| Tiksi, RU
# Processing Record: 21 |<Set 2>| Acajutla, SV
# Processing Record: 22 |<Set 2>| Yatou, CM
# Processing Record: 23 |<Set 2>| Arsk, RU
# Processing Record: 24 |<Set 2>| Aquiraz, BR
# Processing Record: 25 |<Set 2>| Thompson, CA
# Processing Record: 26 |<Set 2>| Provideniya, RU
# Processing Record: 27 |<Set 2>| Bethel, US
# Processing Record: 28 |<Set 2>| Santa Cruz, US
# Processing Record: 29 |<Set 2>| Vryburg, ZA
# Processing Record: 30 |<Set 2>| Mar Del Plata, AR
# Processing Record: 31 |<Set 2>| Bandar-E Lengeh, IR
# Processing Record: 32 |<Set 2>| Wani, IN
# Processing Record: 33 |<Set 2>| Port Lincoln, AU
# Processing Record: 34 |<Set 2>| Cabo San Lucas, MX
# Processing Record: 35 |<Set 2>| Awbari, LY
# Processing Record: 36 |<Set 2>| Xining, CN
# Processing Record: 37 |<Set 2>| Ust-Tsilma, RU
# Processing Record: 38 |<Set 2>| Hambantota, LK
# Processing Record: 39 |<Set 2>| Barrow, AR
# Processing Record: 40 |<Set 2>| Chirongui, YT
# Processing Record: 41 |<Set 2>| Saint George, GR
# Processing Record: 42 |<Set 2>| Port Alfred, ZA
# Processing Record: 43 |<Set 2>| Estelle, US
# Processing Record: 44 |<Set 2>| Chuy, UY
# Processing Record: 45 |<Set 2>| Cape Town, ZA
# Processing Record: 46 |<Set 2>| Hof, DE
# Processing Record: 47 |<Set 2>| Saldanha, PT
# Processing Record: 48 |<Set 2>| Alugan, PH
# Processing Record: 49 |<Set 2>| East London, ZA
# Processing Record: 50 |<Set 2>| Angoche, MZ
# Processing Record: 0 |<Set 3>| Abalak, NE
# Processing Record: 1 |<Set 3>| Gamba, CN
# Processing Record: 2 |<Set 3>| Afikpo, NG
# Processing Record: 3 |<Set 3>| Sur, OM
# Processing Record: 4 |<Set 3>| Zandvoort, NL
# Processing Record: 5 |<Set 3>| Oyama, JP
# City not found. Skipping...
# Processing Record: 7 |<Set 3>| Leeuwarden, NL
# Processing Record: 8 |<Set 3>| Kaitangata, NZ
# City not found. Skipping...
# Processing Record: 10 |<Set 3>| Galle, US
# Processing Record: 11 |<Set 3>| Arraial Do Cabo, BR
# Processing Record: 12 |<Set 3>| Avarua, CK
# Processing Record: 13 |<Set 3>| Yellowknife, CA
# Processing Record: 14 |<Set 3>| Huangmei, CN
# Processing Record: 15 |<Set 3>| Nikolskoye, RU
# Processing Record: 16 |<Set 3>| Huilong, CN
# Processing Record: 17 |<Set 3>| Harper, US
# Processing Record: 18 |<Set 3>| Grindavik, IS
# Processing Record: 19 |<Set 3>| Chelno-Vershiny, RU
# Processing Record: 20 |<Set 3>| Guiratinga, BR
# Processing Record: 21 |<Set 3>| Santiago, CL
# Processing Record: 22 |<Set 3>| Harrisonville, US
# City not found. Skipping...
# City not found. Skipping...
# Processing Record: 25 |<Set 3>| Ryki, PL
# Processing Record: 26 |<Set 3>| Agadez, NE
# City not found. Skipping...
# Processing Record: 28 |<Set 3>| Victoria, BN
# Processing Record: 29 |<Set 3>| Jiangdu, CN
# City not found. Skipping...
# Processing Record: 31 |<Set 3>| Nalut, LY
# Processing Record: 32 |<Set 3>| Timra, SE
# City not found. Skipping...
# Processing Record: 34 |<Set 3>| Magalia, US
# Processing Record: 35 |<Set 3>| Vila Franca Do Campo, PT
# Processing Record: 36 |<Set 3>| San Cristobal, EC
# Processing Record: 37 |<Set 3>| Arlit, NE
# Processing Record: 38 |<Set 3>| Dorogobuzh, RU
# City not found. Skipping...
# Processing Record: 40 |<Set 3>| Terrasini, IT
# Processing Record: 41 |<Set 3>| Byron Bay, AU
# City not found. Skipping...
# City not found. Skipping...
# Processing Record: 44 |<Set 3>| College, US
# Processing Record: 45 |<Set 3>| Chivay, PE
# Processing Record: 46 |<Set 3>| Longyearbyen, NO
# Processing Record: 47 |<Set 3>| Sao Felix Do Xingu, BR
# Processing Record: 48 |<Set 3>| Qaanaaq, GL
# Processing Record: 49 |<Set 3>| Kununurra, AU
# Processing Record: 50 |<Set 3>| Caravelas, BR
# Processing Record: 0 |<Set 4>| Marystown, CA
# Processing Record: 1 |<Set 4>| Kedrovyy, RU
# Processing Record: 2 |<Set 4>| Vila Velha, BR
# Processing Record: 3 |<Set 4>| Itaituba, BR
# Processing Record: 4 |<Set 4>| Filingue, NE
# Processing Record: 5 |<Set 4>| General Pico, AR
# Processing Record: 6 |<Set 4>| Buala, SB
# City not found. Skipping...
# Processing Record: 8 |<Set 4>| Haines Junction, CA
# Processing Record: 9 |<Set 4>| Portobelo, PA
# Processing Record: 10 |<Set 4>| Hobyo, SO
# Processing Record: 11 |<Set 4>| Sabha, LY
# Processing Record: 12 |<Set 4>| Aklavik, CA
# Processing Record: 13 |<Set 4>| Kahului, US
# Processing Record: 14 |<Set 4>| Saint Anthony, US
# Processing Record: 15 |<Set 4>| Shimoda, JP
# Processing Record: 16 |<Set 4>| Airai, TL
# Processing Record: 17 |<Set 4>| Anloga, GH
# Processing Record: 18 |<Set 4>| Souillac, FR
# Processing Record: 19 |<Set 4>| Mandalgovi, MN
# Processing Record: 20 |<Set 4>| Araxa, BR
# Processing Record: 21 |<Set 4>| Coquimbo, CL
# City not found. Skipping...
# Processing Record: 23 |<Set 4>| Lavrentiya, RU
# Processing Record: 24 |<Set 4>| Elizabeth City, US
# Processing Record: 25 |<Set 4>| Teknaf, BD
# Processing Record: 26 |<Set 4>| Tazovskiy, RU
# Processing Record: 27 |<Set 4>| Westonaria, ZA
# Processing Record: 28 |<Set 4>| Newton, US
# Processing Record: 29 |<Set 4>| Juneau, US
# City not found. Skipping...
# City not found. Skipping...
# Processing Record: 32 |<Set 4>| Banda Aceh, ID
# Processing Record: 33 |<Set 4>| Yar-Sale, RU
# Processing Record: 34 |<Set 4>| Shenjiamen, CN
# Processing Record: 35 |<Set 4>| Lagoa, PT
# Processing Record: 36 |<Set 4>| Newport, GB
# Processing Record: 37 |<Set 4>| Saint-Philippe, CA
# City not found. Skipping...
# Processing Record: 39 |<Set 4>| Havoysund, NO
# Processing Record: 40 |<Set 4>| Nanakuli, US
# Processing Record: 41 |<Set 4>| Hohhot, CN
# Processing Record: 42 |<Set 4>| Kolno, PL
# Processing Record: 43 |<Set 4>| Lodja, CD
# Processing Record: 44 |<Set 4>| Verkhnyaya Inta, RU
# Processing Record: 45 |<Set 4>| Ekhabi, RU
# Processing Record: 46 |<Set 4>| Montepuez, MZ
# Processing Record: 47 |<Set 4>| Lorengau, PG
# Processing Record: 48 |<Set 4>| Isverna, RO
# Processing Record: 49 |<Set 4>| Rosarito, CO
# Processing Record: 50 |<Set 4>| Aripuana, BR
# Processing Record: 0 |<Set 5>| Teahupoo, PF
# Processing Record: 1 |<Set 5>| Yulara, AU
# Processing Record: 2 |<Set 5>| Constitucion, MX
# Processing Record: 3 |<Set 5>| Goderich, CA
# Processing Record: 4 |<Set 5>| Saskylakh, RU
# Processing Record: 5 |<Set 5>| Ulaangom, MN
# City not found. Skipping...
# City not found. Skipping...
# Processing Record: 8 |<Set 5>| Kamloops, CA
# Processing Record: 9 |<Set 5>| Narsaq, GL
# Processing Record: 10 |<Set 5>| Ust-Ilimsk, RU
# Processing Record: 11 |<Set 5>| George, NG
# Processing Record: 12 |<Set 5>| Tomatlan, MX
# Processing Record: 13 |<Set 5>| Torres, BR
# Processing Record: 14 |<Set 5>| Kilimatinde, TZ
# City not found. Skipping...
# Processing Record: 16 |<Set 5>| Kavieng, PG
# Processing Record: 17 |<Set 5>| Rameswaram, IN
# Processing Record: 18 |<Set 5>| Hovd, NO
# Processing Record: 19 |<Set 5>| Yeniseysk, RU
# City not found. Skipping...
# Processing Record: 21 |<Set 5>| Mount Isa, AU
# Processing Record: 22 |<Set 5>| Ribeira Grande, PT
# Processing Record: 23 |<Set 5>| Manono, CD
# Processing Record: 24 |<Set 5>| Beringovskiy, RU
# Processing Record: 25 |<Set 5>| Gat, SN
# Processing Record: 26 |<Set 5>| Aswan, EG
# Processing Record: 27 |<Set 5>| Bambous Virieux, MU
# Processing Record: 28 |<Set 5>| Kuhdasht, IR
# Processing Record: 29 |<Set 5>| Hokitika, NZ
# Processing Record: 30 |<Set 5>| Dali, CN
# Processing Record: 31 |<Set 5>| Laguna, MX
# City not found. Skipping...
# Processing Record: 33 |<Set 5>| Severo-Kurilsk, RU
# City not found. Skipping...
# Processing Record: 35 |<Set 5>| Norman Wells, CA
# Processing Record: 36 |<Set 5>| Guerrero Negro, MX
# City not found. Skipping...
# Processing Record: 38 |<Set 5>| Nelson Bay, AU
# Processing Record: 39 |<Set 5>| Sechura, PE
# Processing Record: 40 |<Set 5>| Valleyview, CA
# Processing Record: 41 |<Set 5>| Belyy Yar, RU
# Processing Record: 42 |<Set 5>| Placido De Castro, BR
# Processing Record: 43 |<Set 5>| Tenenkou, ML
# Processing Record: 44 |<Set 5>| Cambridge, GB
# Processing Record: 45 |<Set 5>| Vega De Alatorre, MX
# Processing Record: 46 |<Set 5>| Manokwari, ID
# City not found. Skipping...
# Processing Record: 48 |<Set 5>| Pisco, PE
# Processing Record: 49 |<Set 5>| Ilulissat, GL
# Processing Record: 50 |<Set 5>| Sungaipenuh, ID
# Processing Record: 0 |<Set 6>| Berlevag, NO
# Processing Record: 1 |<Set 6>| Pevek, RU
# Processing Record: 2 |<Set 6>| Hasaki, JP
# City not found. Skipping...
# Processing Record: 4 |<Set 6>| Mega, ET
# Processing Record: 5 |<Set 6>| Faanui, PF
# Processing Record: 6 |<Set 6>| Auki, NG
# Processing Record: 7 |<Set 6>| Alice Springs, AU
# Processing Record: 8 |<Set 6>| Toba, JP
# Processing Record: 9 |<Set 6>| Colonia Leopoldina, BR
# Processing Record: 10 |<Set 6>| The Valley, AI
# Processing Record: 11 |<Set 6>| Belomorsk, RU
# Processing Record: 12 |<Set 6>| Ocampo, PH
# Processing Record: 13 |<Set 6>| Mana, RS
# City not found. Skipping...
# Processing Record: 15 |<Set 6>| Lac Du Bonnet, CA
# Processing Record: 16 |<Set 6>| Tabou, CI
# Processing Record: 17 |<Set 6>| Vestmannaeyjar, IS
# Processing Record: 18 |<Set 6>| Talnakh, RU
# Processing Record: 19 |<Set 6>| Manakara, MG
# Processing Record: 20 |<Set 6>| Ilhabela, BR
# Processing Record: 21 |<Set 6>| Plouzane, FR
# Processing Record: 22 |<Set 6>| Ostrovnoy, RU
# City not found. Skipping...
# Processing Record: 24 |<Set 6>| Fos-Sur-Mer, FR
# Processing Record: 25 |<Set 6>| Cidreira, BR
# Processing Record: 26 |<Set 6>| Port Elizabeth, US
# Processing Record: 27 |<Set 6>| Nagato, JP
# Processing Record: 28 |<Set 6>| Maniitsoq, GL
# Processing Record: 29 |<Set 6>| Karwar, IN
# Processing Record: 30 |<Set 6>| Vardo, US
# Processing Record: 31 |<Set 6>| Santa Catarina De Tepehuanes, MX
# Processing Record: 32 |<Set 6>| Tual, ID
# Processing Record: 33 |<Set 6>| Mayo, CA
# City not found. Skipping...
# Processing Record: 35 |<Set 6>| Tunggol, PH
# Processing Record: 36 |<Set 6>| Luderitz, NA
# Processing Record: 37 |<Set 6>| Straumen, NO
# Processing Record: 38 |<Set 6>| Rocha, UY
# Processing Record: 39 |<Set 6>| Northam, GB
# City not found. Skipping...
# City not found. Skipping...
# Processing Record: 42 |<Set 6>| Rakaia, NZ
# Processing Record: 43 |<Set 6>| Arkhangelsk, RU
# Processing Record: 44 |<Set 6>| Nuuk, GL
# Processing Record: 45 |<Set 6>| Vao, EE
# Processing Record: 46 |<Set 6>| Nemuro, JP
# Processing Record: 47 |<Set 6>| Talara, PE
# Processing Record: 48 |<Set 6>| Majene, ID
# Processing Record: 49 |<Set 6>| Udachnyy, RU
# Processing Record: 50 |<Set 6>| Nhulunbuy, AU
# Processing Record: 0 |<Set 7>| Manaure, CO
# Processing Record: 1 |<Set 7>| Hatta, IN
# Processing Record: 2 |<Set 7>| Mount Gambier, AU
# Processing Record: 3 |<Set 7>| Walvis Bay, NA
# Processing Record: 4 |<Set 7>| Butaritari, KI
# Processing Record: 5 |<Set 7>| Pacific Grove, US
# Processing Record: 6 |<Set 7>| Kysyl-Syr, RU
# City not found. Skipping...
# Processing Record: 8 |<Set 7>| Leningradskiy, RU
# Processing Record: 9 |<Set 7>| Jalu, LY
# Processing Record: 10 |<Set 7>| Erzin, TR
# Processing Record: 11 |<Set 7>| Matara, PE
# Processing Record: 12 |<Set 7>| Katobu, ID
# Processing Record: 13 |<Set 7>| Fortuna, ES
# Processing Record: 14 |<Set 7>| Dunmore East, IE
# Processing Record: 15 |<Set 7>| Sambava, MG
# Processing Record: 16 |<Set 7>| Amga, RU
# Processing Record: 17 |<Set 7>| Port Hardy, CA
# Processing Record: 18 |<Set 7>| Hirara, JP
# City not found. Skipping...
# Processing Record: 20 |<Set 7>| Bolitoc, PH
# Processing Record: 21 |<Set 7>| Prachuap Khiri Khan, TH
# Processing Record: 22 |<Set 7>| Umm Lajj, SA
# City not found. Skipping...
# Processing Record: 24 |<Set 7>| Waingapu, ID
# Processing Record: 25 |<Set 7>| Lazaro Cardenas, MX
# Processing Record: 26 |<Set 7>| Tessalit, ML
# Processing Record: 27 |<Set 7>| Taiyuan, CN
# Processing Record: 28 |<Set 7>| Teguise, ES
# Processing Record: 29 |<Set 7>| Atar, MR
# Processing Record: 30 |<Set 7>| Kavaratti, IN
# Processing Record: 31 |<Set 7>| Yumen, CN
# Processing Record: 32 |<Set 7>| Sao Filipe, CV
# Processing Record: 33 |<Set 7>| Penzance, GB
# Processing Record: 34 |<Set 7>| Kovur, IN
# Processing Record: 35 |<Set 7>| Coihaique, CL
# Processing Record: 36 |<Set 7>| Zlatoust, RU
# Processing Record: 37 |<Set 7>| Morant Bay, JM
# Processing Record: 38 |<Set 7>| Pierre, US
# Processing Record: 39 |<Set 7>| Saquarema, BR
# Processing Record: 40 |<Set 7>| Paciran, ID
# City not found. Skipping...
# Processing Record: 42 |<Set 7>| Bukene, TZ
# Processing Record: 43 |<Set 7>| Tuatapere, NZ
# Processing Record: 44 |<Set 7>| Lakes Entrance, AU
# Processing Record: 45 |<Set 7>| Taltal, CL
# Processing Record: 46 |<Set 7>| Schwabach, DE
# Processing Record: 47 |<Set 7>| Fairbanks, US
# Processing Record: 48 |<Set 7>| Kawalu, ID
# Processing Record: 49 |<Set 7>| Lithakia, GR
# Processing Record: 50 |<Set 7>| Praia, BR
# Processing Record: 0 |<Set 8>| Darnah, LY
# Processing Record: 1 |<Set 8>| Wanaka, NZ
# Processing Record: 2 |<Set 8>| Te Anau, NZ
# Processing Record: 3 |<Set 8>| Dickinson, US
# Processing Record: 4 |<Set 8>| Sept-Iles, CA
# Processing Record: 5 |<Set 8>| Nacozari, MX
# Processing Record: 6 |<Set 8>| Paamiut, GL
# Processing Record: 7 |<Set 8>| Moba, CD
# Processing Record: 8 |<Set 8>| Rantauprapat, ID
# Processing Record: 9 |<Set 8>| Amapa, HN
# Processing Record: 10 |<Set 8>| Rabo De Peixe, PT
# Processing Record: 11 |<Set 8>| Poum, MK
# Processing Record: 12 |<Set 8>| Praya, ID
# Processing Record: 13 |<Set 8>| Ponta Do Sol, BR
# Processing Record: 14 |<Set 8>| Grafton, AU
# Processing Record: 15 |<Set 8>| Talavera De La Reina, ES
# Processing Record: 16 |<Set 8>| Zima, RU
# Processing Record: 17 |<Set 8>| Olinda, EC
# Processing Record: 18 |<Set 8>| Ombessa, CM
# Processing Record: 19 |<Set 8>| Dukat, RS
# Processing Record: 20 |<Set 8>| Pangnirtung, CA
# Processing Record: 21 |<Set 8>| Pacifica, US
# Processing Record: 22 |<Set 8>| Imbituba, BR
# Processing Record: 23 |<Set 8>| Maloye Verevo, RU
# Processing Record: 24 |<Set 8>| Meulaboh, ID
# Processing Record: 25 |<Set 8>| Tamandare, BR
# Processing Record: 26 |<Set 8>| Piacabucu, BR
# Processing Record: 27 |<Set 8>| Mutoko, ZW
# Processing Record: 28 |<Set 8>| Manuk Mangkaw, PH
# Processing Record: 29 |<Set 8>| Muros, ES
# Processing Record: 30 |<Set 8>| San Ignacio, CL
# City not found. Skipping...
# Processing Record: 32 |<Set 8>| Bunia, CD
# Processing Record: 33 |<Set 8>| Faya, SA
# Processing Record: 34 |<Set 8>| Fort Nelson, CA
# Processing Record: 35 |<Set 8>| Jilin, CN
# Processing Record: 36 |<Set 8>| Ishigaki, JP
# Processing Record: 37 |<Set 8>| Katangli, RU
# City not found. Skipping...
# Processing Record: 39 |<Set 8>| Hamilton, BM
# Processing Record: 40 |<Set 8>| Yurty, RU
# Processing Record: 41 |<Set 8>| Chicama, PE
# Processing Record: 42 |<Set 8>| Katsuura, JP
# Processing Record: 43 |<Set 8>| Suixi, CN
# Processing Record: 44 |<Set 8>| Ixtapa, MX
# City not found. Skipping...
# Processing Record: 46 |<Set 8>| Aviles, ES
# Processing Record: 47 |<Set 8>| Chara, GR
# Processing Record: 48 |<Set 8>| Wheeling, US
# Processing Record: 49 |<Set 8>| Helong, CN
# City not found. Skipping...
# City not found. Skipping...
# Processing Record: 1 |<Set 9>| Tamworth, AU
# City not found. Skipping...
# Processing Record: 3 |<Set 9>| Morondava, MG
# Processing Record: 4 |<Set 9>| Slave Lake, CA
# Processing Record: 5 |<Set 9>| Lata, IN
# Processing Record: 6 |<Set 9>| Oum Hadjer, TD
# Processing Record: 7 |<Set 9>| Kirkwall, GB
# Processing Record: 8 |<Set 9>| Jiaxing, CN
# Processing Record: 9 |<Set 9>| Bereda, ES
# Processing Record: 10 |<Set 9>| Klaksvik, FO
# Processing Record: 11 |<Set 9>| Nishihara, JP
# Processing Record: 12 |<Set 9>| Richards Bay, ZA
# Processing Record: 13 |<Set 9>| Plavinas, LV
# City not found. Skipping...
# Processing Record: 15 |<Set 9>| Chegdomyn, RU
# Processing Record: 16 |<Set 9>| Ancud, CL
# Processing Record: 17 |<Set 9>| Dubovyy Umet, RU
# Processing Record: 18 |<Set 9>| Port Hedland, AU
# Processing Record: 19 |<Set 9>| Margate, AU
# Processing Record: 20 |<Set 9>| Macherla, IN
# Processing Record: 21 |<Set 9>| Osoyoos, CA
# Processing Record: 22 |<Set 9>| Kachug, RU
# Processing Record: 23 |<Set 9>| Kabinda, CD
# Processing Record: 24 |<Set 9>| Rio Gallegos, AR
# Processing Record: 25 |<Set 9>| Moussoro, TD
# Processing Record: 26 |<Set 9>| Konevo, BG
# Processing Record: 27 |<Set 9>| Nanortalik, GL
# Processing Record: 28 |<Set 9>| Soltsy, RU
# Processing Record: 29 |<Set 9>| Salamiyah, SY
# Processing Record: 30 |<Set 9>| Ahar, IR
# Processing Record: 31 |<Set 9>| La Ronge, CA
# City not found. Skipping...
# Processing Record: 33 |<Set 9>| Lahij, YE
# Processing Record: 34 |<Set 9>| Seoul, KR
# Processing Record: 35 |<Set 9>| Maltahohe, NA
# Processing Record: 36 |<Set 9>| Inuvik, CA
# Processing Record: 37 |<Set 9>| San Diego, US
# Processing Record: 38 |<Set 9>| Prince Rupert, CA
# Processing Record: 39 |<Set 9>| Iralaya, HN
# Processing Record: 40 |<Set 9>| Isangel, VU
# Processing Record: 41 |<Set 9>| Lebu, ET
# City not found. Skipping...
# Processing Record: 43 |<Set 9>| Kutum, SD
# Processing Record: 44 |<Set 9>| Esperance, TT
# Processing Record: 45 |<Set 9>| Srednekolymsk, RU
# Processing Record: 46 |<Set 9>| Akureyri, IS
# Processing Record: 47 |<Set 9>| Myitkyina, MM
# Processing Record: 48 |<Set 9>| Noumea, NC
# Processing Record: 49 |<Set 9>| Port-Gentil, GA
# Processing Record: 50 |<Set 9>| Ulladulla, AU
# Processing Record: 0 |<Set 10>| Mpika, ZM
# Processing Record: 1 |<Set 10>| Barinas, VE
# Processing Record: 2 |<Set 10>| Mayor Pablo Lagerenza, PY
# Processing Record: 3 |<Set 10>| Volkhov, RU
# City not found. Skipping...
# Processing Record: 5 |<Set 10>| Umm Kaddadah, SD
# Processing Record: 6 |<Set 10>| Touros, BR
# Processing Record: 7 |<Set 10>| San Marco In Lamis, IT
# Processing Record: 8 |<Set 10>| Araouane, ML
# Processing Record: 9 |<Set 10>| Shanghai, CN
# Processing Record: 10 |<Set 10>| Rio Bueno, JM
# Processing Record: 11 |<Set 10>| Bud, NO
# Processing Record: 12 |<Set 10>| Half Moon Bay, US
# City not found. Skipping...
# Processing Record: 14 |<Set 10>| Pahrump, US
# Processing Record: 15 |<Set 10>| Pangody, RU
# Processing Record: 16 |<Set 10>| Debre Sina, ET
# Processing Record: 17 |<Set 10>| San Carlos De Bariloche, AR
# Processing Record: 18 |<Set 10>| Hays, US
# Processing Record: 19 |<Set 10>| Taunggyi, MM
# Processing Record: 20 |<Set 10>| Papar, MY
# Processing Record: 21 |<Set 10>| Doha, QA
# Processing Record: 22 |<Set 10>| Miguel Alves, BR
# Processing Record: 23 |<Set 10>| Hofn, IS
# Processing Record: 24 |<Set 10>| Pingliang, CN
# Processing Record: 25 |<Set 10>| Conde, BR
# Processing Record: 26 |<Set 10>| Bathsheba, BB
# Processing Record: 27 |<Set 10>| Taoudenni, ML
# Processing Record: 28 |<Set 10>| Mareeba, AU
# Processing Record: 29 |<Set 10>| Saint-Francois, FR
# Processing Record: 30 |<Set 10>| Viedma, AR
# Processing Record: 31 |<Set 10>| Sokolo, ML
# Processing Record: 32 |<Set 10>| Codrington, AU
# Processing Record: 33 |<Set 10>| Lahaina, US
# Processing Record: 34 |<Set 10>| Sorong, ID
# Processing Record: 35 |<Set 10>| Ode, NG
# Processing Record: 36 |<Set 10>| Beaverlodge, CA
# Processing Record: 37 |<Set 10>| Sisimiut, GL
# Processing Record: 38 |<Set 10>| Ayni, TJ
# Processing Record: 39 |<Set 10>| Kirakira, SB
# Processing Record: 40 |<Set 10>| Brae, GB
# City not found. Skipping...
# City not found. Skipping...
# Processing Record: 43 |<Set 10>| Dikson, RU
# Processing Record: 44 |<Set 10>| Zhaoyuan, CN
# City not found. Skipping...
# Processing Record: 46 |<Set 10>| Salalah, OM
# Processing Record: 47 |<Set 10>| Qasigiannguit, GL
# Processing Record: 48 |<Set 10>| Mogadishu, SO
# Processing Record: 49 |<Set 10>| Tekeli, KZ
# City not found. Skipping...
# Processing Record: 0 |<Set 11>| Cayenne, GF
# Processing Record: 1 |<Set 11>| Anadyr, RU
# Processing Record: 2 |<Set 11>| Urusha, RU
# Processing Record: 3 |<Set 11>| Hay River, CA
# Processing Record: 4 |<Set 11>| Amot, NO
# Processing Record: 5 |<Set 11>| Puerto Carreno, CO
# Processing Record: 6 |<Set 11>| Barabai, ID
# Processing Record: 7 |<Set 11>| Pyapon, MM
# Processing Record: 8 |<Set 11>| Whitehorse, CA
# Processing Record: 9 |<Set 11>| Belaya Gora, RU
# Processing Record: 10 |<Set 11>| Tromso, NO
# Processing Record: 11 |<Set 11>| Severo-Yeniseyskiy, RU
# Processing Record: 12 |<Set 11>| Valday, RU
# Processing Record: 13 |<Set 11>| Aldan, RU
# Processing Record: 14 |<Set 11>| Mikhaylovka, RU
# Processing Record: 15 |<Set 11>| Hun, BE
# Processing Record: 16 |<Set 11>| Collie, AU
# Processing Record: 17 |<Set 11>| Sinnamary, GF
# Processing Record: 18 |<Set 11>| Jian, IN
# Processing Record: 19 |<Set 11>| Pontes E Lacerda, BR
# Processing Record: 20 |<Set 11>| Birjand, IR
# Processing Record: 21 |<Set 11>| Alakurtti, RU
# Processing Record: 22 |<Set 11>| Storsteinnes, NO
# Processing Record: 23 |<Set 11>| Becerril, CO
# Processing Record: 24 |<Set 11>| Hengyang, CN
# Processing Record: 25 |<Set 11>| Catuday, PH
# Processing Record: 26 |<Set 11>| Roswell, US
# City not found. Skipping...
# Processing Record: 28 |<Set 11>| Ponta Delgada, PT
# Processing Record: 29 |<Set 11>| Lagoa Santa, BR
# Processing Record: 30 |<Set 11>| Khokhlovo, RU
# Processing Record: 31 |<Set 11>| Mitu, IR
# City not found. Skipping...
# Processing Record: 33 |<Set 11>| Antalaha, MG
# Processing Record: 34 |<Set 11>| Mandiana, GN
# Processing Record: 35 |<Set 11>| Charcas, MX
# Processing Record: 36 |<Set 11>| Hervey Bay, AU
# Processing Record: 37 |<Set 11>| Wichian Buri, TH
# Processing Record: 38 |<Set 11>| Mosquera, CO
# Processing Record: 39 |<Set 11>| Polunochnoye, RU
# Processing Record: 40 |<Set 11>| Paracuru, BR
# Processing Record: 41 |<Set 11>| Arman, RU
# Processing Record: 42 |<Set 11>| Kui Buri, TH
# Processing Record: 43 |<Set 11>| Istria, RO
# Processing Record: 44 |<Set 11>| Carbonia, IT
# City not found. Skipping...
# Processing Record: 46 |<Set 11>| Kautokeino, NO
# Processing Record: 47 |<Set 11>| Khandyga, RU
# Processing Record: 48 |<Set 11>| Cooma, AU
# Processing Record: 49 |<Set 11>| Alofi, NU
# Processing Record: 50 |<Set 11>| San Juan, PR
# Processing Record: 0 |<Set 12>| Opuwo, NA
# Processing Record: 1 |<Set 12>| Inongo, CD
# Processing Record: 2 |<Set 12>| Tigil, RU
# Processing Record: 3 |<Set 12>| Bonavista, CA
# Processing Record: 4 |<Set 12>| Onega, RU
# Processing Record: 5 |<Set 12>| Havre-Saint-Pierre, CA
# Processing Record: 6 |<Set 12>| Tevriz, RU
# Processing Record: 7 |<Set 12>| Manadhoo, MV
# Processing Record: 8 |<Set 12>| Salaga, GH
# City not found. Skipping...
# Processing Record: 10 |<Set 12>| San Rafael, AR
# Processing Record: 11 |<Set 12>| Shu, KZ
# Processing Record: 12 |<Set 12>| Miri, NG
# Processing Record: 13 |<Set 12>| Broken Hill, AU
# City not found. Skipping...
# Processing Record: 15 |<Set 12>| Ust-Nera, RU
# Processing Record: 16 |<Set 12>| Maryville, US
# Processing Record: 17 |<Set 12>| Oyem, GA
# Processing Record: 18 |<Set 12>| Petropavlovsk-Kamchatskiy, RU
# Processing Record: 19 |<Set 12>| Sochi, RU
# Processing Record: 20 |<Set 12>| Yaan, NG
# Processing Record: 21 |<Set 12>| Astana, KZ
# Processing Record: 22 |<Set 12>| Palmer, AU
# Processing Record: 23 |<Set 12>| Huarmey, PE
# Processing Record: 24 |<Set 12>| Moose Factory, CA
# Processing Record: 25 |<Set 12>| Maraa, BR
# Processing Record: 26 |<Set 12>| Rawson, AR
# City not found. Skipping...
# Processing Record: 28 |<Set 12>| Bratsk, RU
# Processing Record: 29 |<Set 12>| Meiringen, CH
# Processing Record: 30 |<Set 12>| Dhadar, IN
# Processing Record: 31 |<Set 12>| Waipawa, NZ
# Processing Record: 32 |<Set 12>| Pimentel, BR
# Processing Record: 33 |<Set 12>| Vredendal, ZA
# Processing Record: 34 |<Set 12>| Camacha, PT
# Processing Record: 35 |<Set 12>| Gumia, IN

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
cities_df.dropna(inplace=True)
cities_df.count()
# Out:
# City                535
# Country             535
# Temperature (F)     535
# Latitude            535
# Longitude           535
# Humidity (%)        535
# Cloudiness (%)      535
# Wind Speed (mph)    535
# dtype: int64

# %%
cities_df.to_csv(r'..\dataframe.csv')
cities_df.head()
# Out:
#           City Country Temperature (F) Latitude Longitude Humidity (%)  \
# 0        roald      no           30.99    62.58      6.12           59
# 1     hermanus      za           61.88   -34.42     19.24           93
# 2  clyde river      ca            10.4    70.47    -68.59           85
# 3        bluff      nz            78.6   -23.58    149.07           55
# 4  tuktoyaktuk      ca             8.6    69.44   -133.03           84
#
#   Cloudiness (%) Wind Speed (mph)
# 0              0            18.34
# 1              0             2.48
# 2             68             2.48
# 3              0             6.29
# 4             75             6.93

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
plt.scatter(cities_df["Latitude"],
           cities_df["Temperature (F)"], c=cities_df["Temperature (F)"],
           edgecolor="silver", linewidths = 1.5, marker="8",
           cmap='plasma', alpha=0.75, label="City")

plt.style.use('seaborn')
plt.title(f"City Latitude vs. Max Temperature {datetime.now().strftime('%m/%d/%Y')}")
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True, color='black')
plt.xlim([-80, 105])
plt.ylim([-10, 100])
plt.savefig("../Images/Lat_Temp.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
plt.scatter(cities_df["Latitude"],
           cities_df["Humidity (%)"], c=cities_df["Humidity (%)"],
           edgecolor="silver", linewidths = 1.15, marker="8",
           cmap='GnBu', alpha=0.75, label="City")

plt.style.use('seaborn')
plt.title(f"City Latitude vs Humidity (%) {datetime.now().strftime('%m/%d/%Y')}")
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True,color='black')
plt.xlim([-65, 85])
plt.ylim([-2, 110])
plt.savefig("../Images/Lat_Humid.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
plt.scatter(cities_df["Latitude"],
           cities_df["Cloudiness (%)"], c=cities_df["Cloudiness (%)"],
           edgecolor="silver", linewidths = 1.5, marker="8",
           cmap='bone_r', alpha=0.75, label="City")

plt.style.use('seaborn')
plt.title(f"City Latitude vs Cloudiness (%) {datetime.now().strftime('%m/%d/%Y')}")
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True,color='black')
plt.xlim([-65, 85])
plt.ylim([-5, 110])
plt.savefig("../Images/Lat_cloud.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
plt.scatter(cities_df["Latitude"],
           cities_df["Wind Speed (mph)"], c=cities_df["Wind Speed (mph)"],
           edgecolor="silver", linewidths = 1.5, marker="8",
           cmap='YlGnBu', alpha=0.75, label="City")

plt.style.use('seaborn')
plt.title(f"City Latitude vs Wind Speed (mph) {datetime.now().strftime('%m/%d/%Y')}")
plt.ylabel("Wind Speed (mph))")
plt.xlabel("Latitude")
plt.grid(True,color='black')
plt.xlim([-70, 90])
plt.ylim([-5, 40])
plt.savefig("../Images/Lat_windspd.png")
plt.show()
